# %%
# Pandas Worksheet

# %%
# index are rows
# columns are columns

# %%
import pandas as pd

# %%
df=pd.read_csv('loans.csv')
df
# Out:
#       loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  \
# 0         10000        10000            10000  36 months    0.1033
# 1          4000         4000             4000  36 months    0.2340
# 2          5000         5000             5000  36 months    0.1797
# 3          9600         9600             9600  36 months    0.1298
# 4          2500         2500             2500  36 months    0.1356
# ...         ...          ...              ...        ...       ...
# 3781      40000        40000            40000  36 months    0.1180
# 3782      10000        10000            10000  60 months    0.1072
# 3783      12550        12550            12550  36 months    0.0702
# 3784       8000         8000             8000  36 months    0.0702
# 3785      15000        15000            15000  60 months    0.1992
#
#       installment grade sub_grade                             emp_title  \
# 0          324.23     B        B1                                   NaN
# ...

# %%
df["funded_amnt"].sum()
# Out:
# 61003275

# %%
df["funded_amnt"].mean()
# Out:
# 16112.856576862123

# %%
df["funded_amnt"] == df["loan_amnt"]
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3781    True
# 3782    True
# 3783    True
# 3784    True
# 3785    True
# Length: 3786, dtype: bool

# %%
df[df["loan_status"] != "Current"] # df to df when you want to display all the data
# Out:
#       loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  \
# 36        25000        25000            25000  36 months    0.1298
# 48        35000        35000            35000  60 months    0.1894
# 49         3000         3000             3000  36 months    0.1797
# 58        40000        40000            40000  60 months    0.1614
# 65        35000        35000            35000  60 months    0.1298
# ...         ...          ...              ...        ...       ...
# 3644      10000        10000            10000  36 months    0.0819
# 3655      16000        16000            16000  36 months    0.1356
# 3702       6000         6000             6000  36 months    0.2089
# 3715      40000        40000            40000  36 months    0.0819
# 3783      12550        12550            12550  36 months    0.0702
#
#       installment grade sub_grade                             emp_title  \
# 36         842.11     B        B5                                   NaN
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3786, step=1)

# %%
list1 = [10,20,30,40,50]
list1
# Out:
# [10, 20, 30, 40, 50]

# %%
pd.Series(list1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.DataFrame(list1)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
dict1 = {"charles":[1,2,34,5,6,78]}
dict1
# Out:
# {'charles': [1, 2, 34, 5, 6, 78]}

# %%
pd.DataFrame(dict1)
# Out:
#    charles
# 0        1
# 1        2
# 2       34
# 3        5
# 4        6
# 5       78

# %%
pd.Series(dict1)
# Out:
# charles    [1, 2, 34, 5, 6, 78]
# dtype: object

# %%
df.describe() #for numeric variables, gives stats
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv     int_rate  installment  \
# count   3786.000000   3786.000000      3786.000000  3786.000000  3786.000000
# mean   16112.856577  16112.856577     16109.627575     0.126338   462.116075
# std    10385.138405  10385.138405     10387.371112     0.048185   286.093587
# min     1000.000000   1000.000000       750.000000     0.060000    30.640000
# 25%     8000.000000   8000.000000      8000.000000     0.081900   249.080000
# 50%    14000.000000  14000.000000     14000.000000     0.118000   389.125000
# 75%    22000.000000  22000.000000     22000.000000     0.150200   622.680000
# max    40000.000000  40000.000000     40000.000000     0.307500  1409.050000
#
#          annual_inc
# count  3.786000e+03
# mean   8.559789e+04
# std    6.370011e+04
# min    0.000000e+00
# 25%    5.000000e+04
# 50%    7.048764e+04
# 75%    1.020000e+05
# max    1.120000e+06

# %%
df["loan_amnt"]
# Out:
# 0       10000
# 1        4000
# 2        5000
# 3        9600
# 4        2500
#         ...
# 3781    40000
# 3782    10000
# 3783    12550
# 3784     8000
# 3785    15000
# Name: loan_amnt, Length: 3786, dtype: int64

# %%
df.head(10)  #gives 5 rows by default (pass number for more) displays the first n rows
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000            10000  36 months    0.1033       324.23
# 1       4000         4000             4000  36 months    0.2340       155.68
# 2       5000         5000             5000  36 months    0.1797       180.69
# 3       9600         9600             9600  36 months    0.1298       323.37
# 4       2500         2500             2500  36 months    0.1356        84.92
# 5      30000        30000            30000  60 months    0.1894       777.23
# 6      23000        23000            23000  60 months    0.2089       620.81
# 7      32075        32075            32075  60 months    0.1180       710.26
# 8       8000         8000             8000  36 months    0.2340       311.35
# 9      10000        10000            10000  60 months    0.1992       264.50
#
#   grade sub_grade           emp_title emp_length home_ownership  annual_inc  \
# ...

# %%
df.columns  # returns all column headings
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'pymnt_plan', 'purpose'],
#       dtype='object')

# %%
df['interest_gained']=df['loan_amnt']*df['int_rate']

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000            10000  36 months    0.1033       324.23
# 1       4000         4000             4000  36 months    0.2340       155.68
# 2       5000         5000             5000  36 months    0.1797       180.69
# 3       9600         9600             9600  36 months    0.1298       323.37
# 4       2500         2500             2500  36 months    0.1356        84.92
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     B        B5             NaN        NaN       MORTGAGE     35704.0
# 4     C        C1            Chef  10+ years           RENT     55000.0
#
# ...

# %%
df['interest_gained']
# Out:
# 0       1033.00
# 1        936.00
# 2        898.50
# 3       1246.08
# 4        339.00
#          ...
# 3781    4720.00
# 3782    1072.00
# 3783     881.01
# 3784     561.60
# 3785    2988.00
# Name: interest_gained, Length: 3786, dtype: float64

# %%
type(df['interest_gained'])
# Out:
# pandas.core.series.Series

# %%
type(df[['interest_gained']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['interest_gained']].head() #frame and series are interchangeable, but multiple series make up a dataframe
# Out:
#    interest_gained
# 0          1033.00
# 1           936.00
# 2           898.50
# 3          1246.08
# 4           339.00

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000            10000  36 months    0.1033       324.23
# 1       4000         4000             4000  36 months    0.2340       155.68
# 2       5000         5000             5000  36 months    0.1797       180.69
# 3       9600         9600             9600  36 months    0.1298       323.37
# 4       2500         2500             2500  36 months    0.1356        84.92
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     B        B5             NaN        NaN       MORTGAGE     35704.0
# 4     C        C1            Chef  10+ years           RENT     55000.0
#
# ...

# %%
df['grade'].value_counts() #sub total of all count by value
# Out:
# A    1213
# B    1076
# C     905
# D     411
# E     179
# F       2
# Name: grade, dtype: int64

# %%
df.isnull().mean()*100 #returns percent values for nulls of each column heading
# Out:
# loan_amnt               0.000000
# funded_amnt             0.000000
# funded_amnt_inv         0.000000
# term                    0.000000
# int_rate                0.000000
# installment             0.000000
# grade                   0.000000
# sub_grade               0.000000
# emp_title              14.685684
# emp_length              7.342842
# home_ownership          0.000000
# annual_inc              0.000000
# verification_status     0.000000
# issue_d                 0.000000
# loan_status             0.000000
# pymnt_plan              0.000000
# purpose                 0.000000
# interest_gained         0.000000
# dtype: float64

# %%
df.isnull().sum() #returns count of null by column heading
# Out:
# loan_amnt                0
# funded_amnt              0
# funded_amnt_inv          0
# term                     0
# int_rate                 0
# installment              0
# grade                    0
# sub_grade                0
# emp_title              556
# emp_length             278
# home_ownership           0
# annual_inc               0
# verification_status      0
# issue_d                  0
# loan_status              0
# pymnt_plan               0
# purpose                  0
# interest_gained          0
# dtype: int64

# %%
df.duplicated().sum() #returns count of duplicate rows
# Out:
# 2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000            10000  36 months    0.1033       324.23
# 1       4000         4000             4000  36 months    0.2340       155.68
# 2       5000         5000             5000  36 months    0.1797       180.69
# 3       9600         9600             9600  36 months    0.1298       323.37
# 4       2500         2500             2500  36 months    0.1356        84.92
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     B        B5             NaN        NaN       MORTGAGE     35704.0
# 4     C        C1            Chef  10+ years           RENT     55000.0
#
# ...

# %%
loan_amt_df=df['loan_amnt'].value_counts().to_frame()

# %%
loan_amt_df.head()
# Out:
#        loan_amnt
# 10000        383
# 20000        260
# 15000        228
# 40000        174
# 5000         167

# %%
loan_amt_df.columns=['num_entries']

# %%
loan_amt_df.head()
# Out:
#        num_entries
# 10000          383
# 20000          260
# 15000          228
# 40000          174
# 5000           167

# %%
loan_amt_df.sort_index(inplace=True)

# %%
loan_amt_df.head()
# Out:
#       num_entries
# 1000           31
# 1200            5
# 1250            1
# 1300            2
# 1400            3

# %%
plt.figure(figsize=(20,10))   #setting canvas size
x=loan_amt_df['num_entries'].index
y=loan_amt_df['num_entries'].values
plt.plot(x,y)

# %%
plt.figure(figsize=(20,10))   #setting canvas size
x=loan_amt_df['num_entries'].index
y=loan_amt_df['num_entries'].values
plt.scatter(x,y)
plt.xlabel('Loan Amounts')
plt.ylabel('Number of Loans')
plt.title('Distribution of Loan Amounts',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of Loan Amounts')

# %%
df['loan_status'].value_counts()
# Out:
# Current               3615
# Fully Paid             150
# Late (31-120 days)      16
# In Grace Period          3
# Late (16-30 days)        2
# Name: loan_status, dtype: int64

# %%
df['loan_status'].str.contains('Late').astype(int)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3781    0
# 3782    0
# 3783    0
# 3784    0
# 3785    0
# Name: loan_status, Length: 3786, dtype: int32

# %%
df['Late_Payment']=df['loan_status'].str.contains('Late').astype(int)

# %%
df['Late_Payment'].value_counts()
# Out:
# 0    3768
# 1      18
# Name: Late_Payment, dtype: int64

# %%
df[df['loan_status']!='Late (31-120 days)']

# %%
df[df['loan_status']=='Late (31-120 days)']

# %%
df[["loan_amnt","funded_amnt"]] # need 2 brackets to display/pass two different columns
# Out:
#       loan_amnt  funded_amnt
# 0         10000        10000
# 1          4000         4000
# 2          5000         5000
# 3          9600         9600
# 4          2500         2500
# ...         ...          ...
# 3781      40000        40000
# 3782      10000        10000
# 3783      12550        12550
# 3784       8000         8000
# 3785      15000        15000
#
# [3786 rows x 2 columns]

# %%
def plot_correlation(df, var_name):
    target_var = 'late_payment' # the matching column in df
    df2 = pd.get_dummies(df[[var_name, target_var]], columns=[var_name])
    x_labels = []
    labels = list(df2.columns[1:])
    for i in range(0,len(labels)):
        x_labels.append(labels[i].split('_')[-1])

    df3 = df2.corrwith(df2[target_var])[1:]
    df3.index = x_labels

    df3.plot.bar(
            figsize = (20, 10), title = "Correlation with {}".format(var_name), fontsize = 15, grid = True)
    plt.title("Correlation between {} and Fraud".format(var_name), fontsize=20)
    plt.xlabel(var_name, fontsize=20)
    plt.ylabel("Correlation with {}".format(target_var), fontsize=20)

# %%
plot_correlation(df, 'grade')

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000            10000  36 months    0.1033       324.23
# 1       4000         4000             4000  36 months    0.2340       155.68
# 2       5000         5000             5000  36 months    0.1797       180.69
# 3       9600         9600             9600  36 months    0.1298       323.37
# 4       2500         2500             2500  36 months    0.1356        84.92
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     B        B5             NaN        NaN       MORTGAGE     35704.0
# 4     C        C1            Chef  10+ years           RENT     55000.0
#
# ...

# %%
df['Late_Payment'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Late_Payment, dtype: int32
